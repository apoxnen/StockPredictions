# %% [markdown]
# # Predicting stock prices with support vector models

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import style
from models import stocks
prices = []
dates = []

stocks.get_data('AMZN.csv', dates, prices)

predict_price = stocks.predict_prices(dates, prices, 15)
print(predict_price)
# Out:
# (1445.8025361095717, 1451.8457134285966, 1452.3139160056467)

# %%
stocks.twitter_sentiment("AMZN")
